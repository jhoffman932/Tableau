# %%
import os

# %%
import os.path

# %%
import csv
from datetime import datetime
import pandas as pd
import numpy as np
import glob

# %%
# Change to top level of extracted data archive
os.chdir("C:/Users/jhoff/Desktop/TableauHW/citidata")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2519ecd4f847> in <module>()
#       1 # Change to top level of extracted data archive
# ----> 2 os.chdir("C:/Users/jhoff/Desktop/TableauHW/citidata")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:/Users/jhoff/Desktop/TableauHW/citidata'

# %%
df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('', "*.csv"))))

# %%
df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1               370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2              1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3               383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4               377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
# 5               497  2018-09-01 10:23:15.7840  2018-09-01 10:31:32.9800
# 6               426  2018-09-01 10:49:48.2870  2018-09-01 10:56:54.3760
# 7               138  2018-09-01 11:01:00.9880  2018-09-01 11:03:19.2540
# 8               280  2018-09-01 11:41:15.9230  2018-09-01 11:45:56.1620
# 9              2026  2018-09-01 11:43:57.4740  2018-09-01 12:17:44.1050
# 10             2020  2018-09-01 11:44:12.4460  2018-09-01 12:17:52.9200
# 11             2088  2018-09-01 11:51:51.0010  2018-09-01 12:26:39.2900
# ...

# %%
missing_df = df[(df['start station latitude']==0) |                         # selects rows with missing data
                (df['start station longitude']==0) |                         # pipe (|) represents logical
                (df['end station latitude']==0) |
                (df['end station longitude']==0)]

# %%
df = df.drop(missing_df.index)                                 # drops rows with missing data

# %%
df.to_csv("september.csv", index=False)
